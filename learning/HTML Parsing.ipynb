# %%
import requests
import json
from pprint import pprint
import webbrowser
from bs4 import BeautifulSoup as bs

# %%
example_html = """
<!DOCTYPE html>
<head>
    <title>Car Buying Web Page</title>
    <link rel="stylesheet" type="text/css" href="example.css">
</head>
<body>
<h1 id="main-page-title">Used Tesla Cars in Your Area</h1>

<ul class="listings">
    <li id="vin3827" class="auto-listing">
        <div>
            <h2 class="model">2017 Tesla Model 3</h2>
            <p class="price">$34,586</p>
            <p class="description">
                A wonderful car and a great deal.</p>
        </div>
    </li>
    <li id="vin9381" class="auto-listing">
        <div>
            <h2 class="model">2019 Tesla Model 3</h2>
            <p class="price">$37,938</p>
            <p class="description">
                Great deal. Low mileage.</p>
        </div>
    </li>
    <li id="vin2938" class="auto-listing">
        <div>
            <h2 class="model">2018 Tesla Model 3</h2>
            <p class="price">$36,263</p>
            <p class="description">
                Bright red. Attract attention.</p>
        </div>
    </li>
</ul>
<div class="scratchpad">
    <textarea rows="2" class="edit-box"></textarea>
</div>
</body>
</html>
"""

# %%
soup = bs(example_html)

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html><head>
# <title>Car Buying Web Page</title>
# <link href="example.css" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <h1 id="main-page-title">Used Tesla Cars in Your Area</h1>
# <ul class="listings">
# <li class="auto-listing" id="vin3827">
# <div>
# <h2 class="model">2017 Tesla Model 3</h2>
# <p class="price">$34,586</p>
# <p class="description">
#                 A wonderful car and a great deal.</p>
# </div>
# </li>
# <li class="auto-listing" id="vin9381">
# <div>
# <h2 class="model">2019 Tesla Model 3</h2>
# <p class="price">$37,938</p>
# <p class="description">
#                 Great deal. Low mileage.</p>
# </div>
# </li>
# <li class="auto-listing" id="vin2938">
# <div>
# <h2 class="model">2018 Tesla Model 3</h2>
# <p class="price">$36,263</p>
# <p class="description">
#                 Bright red. Attract attention.</p>
# </div>
# </li>
# </ul>
# <div class="scratchpad">
# <textarea class="edit-box" rows="2"></textarea>
# </div>
# </body>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Car Buying Web Page
#   </title>
#   <link href="example.css" rel="stylesheet" type="text/css"/>
#  </head>
#  <body>
#   <h1 id="main-page-title">
#    Used Tesla Cars in Your Area
#   </h1>
#   <ul class="listings">
#    <li class="auto-listing" id="vin3827">
#     <div>
#      <h2 class="model">
#       2017 Tesla Model 3
#      </h2>
#      <p class="price">
#       $34,586
#      </p>
#      <p class="description">
#       A wonderful car and a great deal.
#      </p>
#     </div>
#    </li>
#    <li class="auto-listing" id="vin9381">
#     <div>
#      <h2 class="model">
#       2019 Tesla Model 3
#      </h2>
#      <p class="price">
#       $37,938
#      </p>
#      <p class="description">
#       Great deal. Low mileage.
#      </p>
#     </div>
#    </li>
#    <li class="auto-listing" id="vin2938">
#     <div>
#      <h2 class="model">
#       2018 Tesla Model 3
#      </h2>
#      <p class="price">
#       $36,263
# ...

# %%
soup.link
# Out:
# <link href="example.css" rel="stylesheet" type="text/css"/>

# %%
soup.title
# Out:
# <title>Car Buying Web Page</title>

# %%
soup.body
# Out:
# <body>
# <h1 id="main-page-title">Used Tesla Cars in Your Area</h1>
# <ul class="listings">
# <li class="auto-listing" id="vin3827">
# <div>
# <h2 class="model">2017 Tesla Model 3</h2>
# <p class="price">$34,586</p>
# <p class="description">
#                 A wonderful car and a great deal.</p>
# </div>
# </li>
# <li class="auto-listing" id="vin9381">
# <div>
# <h2 class="model">2019 Tesla Model 3</h2>
# <p class="price">$37,938</p>
# <p class="description">
#                 Great deal. Low mileage.</p>
# </div>
# </li>
# <li class="auto-listing" id="vin2938">
# <div>
# <h2 class="model">2018 Tesla Model 3</h2>
# <p class="price">$36,263</p>
# <p class="description">
#                 Bright red. Attract attention.</p>
# </div>
# </li>
# </ul>
# <div class="scratchpad">
# <textarea class="edit-box" rows="2"></textarea>
# </div>
# </body>

# %%
soup.body.parent.name
# Out:
# 'html'

# %%
html = """
    <h1><a /><b><th <td>
"""

# %%
soup = bs(html)
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <h1>
#    <a>
#    </a>
#    <b>
#    </b>
#    <th>
#    </th>
#   </h1>
#  </body>
# </html>

# %%
soup = bs(html,'lxml')
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <h1>
#    <a>
#    </a>
#    <b>
#    </b>
#    <th>
#    </th>
#   </h1>
#  </body>
# </html>

# %%
soup = bs(html,'html5')
print(soup.prettify())
# Out:
# <html>
#  <head>
#  </head>
#  <body>
#   <h1>
#    <a>
#     <b>
#     </b>
#    </a>
#   </h1>
#  </body>
# </html>

# %%
soup = bs(html, 'html.parser')
print(soup.prettify())
# Out:
# <h1>
#  <a>
#  </a>
#  <b>
#   <th <td="">
#   </th>
#  </b>
# </h1>

# %%
soup = bs(html,'html5lib')
print(soup.prettify())
# Out:
# <html>
#  <head>
#  </head>
#  <body>
#   <h1>
#    <a>
#     <b>
#     </b>
#    </a>
#   </h1>
#  </body>
# </html>

# %%
soup = bs(html,'xml')
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <h1>
#  <a/>
#  <b>
#   <th>
#    <td/>
#   </th>
#  </b>
# </h1>

# %%
soup = bs(html,'lxml-xml')
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <h1>
#  <a/>
#  <b>
#   <th>
#    <td/>
#   </th>
#  </b>
# </h1>

# %%
resp = requests.get("https://google.com")
resp
# Out:
# <Response [200]>

# %%
soup = bs(resp.text,'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en">
#  <head>
#   <meta content="Search the world's information, including webpages, images, videos and more. Google has many special features to help you find exactly what you're looking for." name="description"/>
#   <meta content="noodp" name="robots"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <title>
#    Google
#   </title>
#   <script nonce="30upHZpffMpowbjiBn6o8g==">
#    (function(){window.google={kEI:'Bn5cYLW0NYvL_QbIvoSgBQ',kEXPI:'31',kBL:'dmwM'};google.sn='webhp';google.kHL='en';})();(function(){
# var f,h=[];function k(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||f}function l(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}
# ...

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
resp = requests.get("https://www.net.grimaldi.co.uk/GNET45/Pages_GAtlas/WFContainerTracking")
resp
# Out:
# <Response [200]>

# %%
with open("C:/Users/Chisom/Downloads/GNET Grimaldi Corporate.html") as html_code:
    soup = bs(html_code,'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="/GNET45/DXR.axd?r=1_72,1_66,1_67,1_68,1_71,1_249,1_248,1_206,1_203,1_205,1_202-bm6Zi" rel="stylesheet" type="text/css"/>
#   <link href="../App_Themes/Theme1/bootstrap.min.css" rel="stylesheet" type="text/css"/>
#   <link href="../App_Themes/Theme1/jquery-ui-1.10.3.custom.min.css" rel="stylesheet" type="text/css"/>
#   <link href="../App_Themes/Theme1/xnetBootstrapFix.css" rel="stylesheet" type="text/css"/>
#   <link href="../App_Themes/Theme1/xnetGNET.css" rel="stylesheet" type="text/css"/>
#   <link href="../App_Themes/Theme1/xnetJQuery.css" rel="stylesheet" type="text/css"/>
#   <link href="../App_Themes/Theme1/xnetSkin.css" rel="stylesheet" type="text/css"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    GNET Grimaldi Corporate
#   </title>
#   <script src="../Scripts/jquery-1.10.2.min.js" type="text/javascript">
#   </script>
# ...

# %%
soup.title
# Out:
# <title>
# 	 GNET Grimaldi Corporate
# </title>

# %%
tag = soup.title
type(tag)
# Out:
# bs4.element.Tag

# %%
tag = soup.h3
tag
# Out:
# <h3 style="margin-top:0px; border-bottom:1px solid #707070;">SAILING SCHEDULES</h3>

# %%
tag.name
# Out:
# 'h3'

# %%
tag.name = "user_defined"

# %%
tag.name
# Out:
# 'user_defined'

# %%
tag
# Out:
# <user_defined style="margin-top:0px; border-bottom:1px solid #707070;">SAILING SCHEDULES</user_defined>

# %%
tag = soup.a
tag
# Out:
# <a href="javascript:CallPage('../Pages_ScheduleInfo/WFSchedule.aspx')"> POINT TO POINT SCHEDULE ENQUIRY</a>

# %%
tag['href']
# Out:
# "javascript:CallPage('../Pages_ScheduleInfo/WFSchedule.aspx')"

# %%
tag.attrs
# Out:
# {'href': "javascript:CallPage('../Pages_ScheduleInfo/WFSchedule.aspx')"}

# %%
tag = soup.img
tag
# Out:
# <img alt="Descending" class="dxGridView_gvHeaderSortDown dx-vam" src="/GNET45/DXR.axd?r=1_85-bm6Zi" style="margin-left:5px;"/>

# %%
tag.attrs
# Out:
# {'class': ['dxGridView_gvHeaderSortDown', 'dx-vam'],
#  'src': '/GNET45/DXR.axd?r=1_85-bm6Zi',
#  'alt': 'Descending',
#  'style': 'margin-left:5px;'}

# %%
tag = soup.b
tag
# Out:
# <b class="dx-clear"></b>

# %%
tag['class']
# Out:
# ['dx-clear']

# %%
tag = soup.li
tag
# Out:
# <li><a href="javascript:CallPage('../Pages_ScheduleInfo/WFSchedule.aspx')"> POINT TO POINT SCHEDULE ENQUIRY</a></li>

# %%
tag.attrs
# Out:
# {}

# %%
tag.string
# Out:
# ' POINT TO POINT SCHEDULE ENQUIRY'

# %%
comment = soup.i
comment
